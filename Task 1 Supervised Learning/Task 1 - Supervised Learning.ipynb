# %% [markdown]
# # The Sparks Foundation
# ### Task 1 - Supervised Learnig

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ### Importing the file

# %%
df = pd.read_csv('http://bit.ly/w-data ')
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
plt.scatter(df['Hours'],df['Scores'])
plt.xlabel('Hours')
plt.ylabel('Scores')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Scores')

# %% [markdown]
# Splitting the values from target

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %% [markdown]
# Training the model

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train,y_train)

# %%
plt.figure()
line = reg.coef_*X + reg.intercept_
plt.scatter(X,y)
plt.plot(X,line)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Checking the score

# %%
from sklearn.metrics import r2_score,mean_absolute_error
predict = reg.predict(X_test)
print('R2 Score = {}'.format(r2_score(y_test,predict)))
print('Mean Absolute Error = {}'.format(mean_absolute_error(y_test,predict)))
# Out:
# R2 Score = 0.9784662540159219
# Mean Absolute Error = 3.6576279282358306

# %% [markdown]
# Predicting value of 9.25

# %%
hours = np.array(9.25)
own_pred = reg.predict(hours.reshape(1,-1))
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.44281555356989
